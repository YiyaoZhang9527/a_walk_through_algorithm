# %% [markdown]
# ## 勾股定理&毕达哥拉斯定理
#
# #### 数学的推理世界和测量世界的区别
# ##### 1.测量和逻辑推理的区别
# 观察的经验可以给我们启发，但是他不能成为得到数学结论的依据
# ##### 2.证实和证明的区别
# 自然科学很多定律和理论不仅存在一个被推翻的可能性。
# 但是数学的结论只能从逻辑出发，通过归纳和演绎得出来。他必须完全正确没有例外，但凡有一个例外就要被完全否定
# ##### 3.数学结论的相对性和数学结论的绝对性区别
